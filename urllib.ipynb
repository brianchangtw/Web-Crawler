# %%
from urllib.request import urlopen
html = urlopen('https://www.twbiobank.org.tw/new_web/') .read().decode('utf-8')
print(html)
# Out:
# <!DOCTYPE html>
# <html lang="en" class="no-js">
# <head>
# <meta charset="UTF-8" />
# <title>臺灣人體生物資料庫</title>
# <meta name="viewport" content="width=990">
# <meta name="Author" content="Designer:李明[leemingle.com]">
# <link rel="icon" href="img/favicon.ico" type="image/x-icon"/>
# <link rel="shortcut icon" href="img/favicon.ico" type="image/x-icon"/>
# <link rel="shortcut icon" type="image/png" href="img/favicon.png"/>
# <link rel="shortcut icon" type="image/png" href="img/favicon.png"/>
# <link rel="stylesheet" type="text/css" href="css/bootstrap.min.css" />
# <link rel="stylesheet" type="text/css" href="css/jPushMenu.css" />
# <link rel="stylesheet" type="text/css" href="css/style.css" />
# <link rel="stylesheet" type="text/css" href="css/index.css" />
# <link rel="stylesheet" type="text/css" href="css/icon.css" />
# <link rel="stylesheet" type="text/css" href="css/rwd.css" />
# <script src='https://ajax.googleapis.com/ajax/libs/jquery/1.11.0/jquery.min.js'></script>
# ...

# %%
import re
res = re.findall(r"<title>(.+?)</title>", html)
print("\nPage title is: ", res[0])
# Out:
# Page title is:  臺灣人體生物資料庫

# %%
res = re.findall(r'href="(.*?)"', html)
print("\nAll links: ", res)
# Out:
# All links:  ['img/favicon.ico', 'img/favicon.ico', 'img/favicon.png', 'img/favicon.png', 'css/bootstrap.min.css', 'css/jPushMenu.css', 'css/style.css', 'css/index.css', 'css/icon.css', 'css/rwd.css', '#scroll_top', '#scroll_chart', '#scroll_other', '#scroll_info', '#scroll_flow', '#scroll_join', '#scroll_contact', '#scroll_partner', 'index.php', 'about.html', 'activity.php', 'about-export.html', 'join-flow-before.html', 'download.html', 'faq.html', 'contact.html', 'https://www.youtube.com/watch?v=tVIHlchyOCs', 'index.php', 'index.php', 'about.html', 'activity.php', 'about-export.html', 'join-flow-before.html', 'download.html', 'faq.html', 'contact.html', 'https://www.youtube.com/watch?v=tVIHlchyOCs', '../new_web_en/index.php', 'index.php', 'news.php', 'about.php', 'activity.php', 'about-export.php', 'join-flow-before.php', 'download.php', 'agree.php', 'consultation.php', 'faq.php', 'contact.php', 'mv-5.php?year=106', 'media-3.php?year=105', 'job.php', 'index.php', '../new_web_en/inde
# ...
