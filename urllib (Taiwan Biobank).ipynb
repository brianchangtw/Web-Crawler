# %%
from urllib.request import urlopen
html = urlopen('https://www.twbiobank.org.tw/new_web_en/index.php').read().decode('utf-8')
print(html)
# Out:
# <!DOCTYPE html>
# <html lang="en" class="no-js">
# <head>
# <meta charset="UTF-8" />
# <title>臺灣人體生物資料庫</title>
# <meta name="viewport" content="width=990">
# <meta name="Author" content="Designer:李明[leemingle.com]">
# <link rel="icon" href="img/favicon.ico" type="image/x-icon"/>
# <link rel="shortcut icon" href="img/favicon.ico" type="image/x-icon"/>
# <link rel="shortcut icon" type="image/png" href="img/favicon.png"/>
# <link rel="shortcut icon" type="image/png" href="img/favicon.png"/>
# <link rel="stylesheet" type="text/css" href="css/bootstrap.min.css" />
# <link rel="stylesheet" type="text/css" href="css/jPushMenu.css" />
# <link rel="stylesheet" type="text/css" href="css/style.css" />
# <link rel="stylesheet" type="text/css" href="css/index.css" />
# <link rel="stylesheet" type="text/css" href="css/icon.css" />
# <link rel="stylesheet" type="text/css" href="css/rwd.css" />
# <script src='https://ajax.googleapis.com/ajax/libs/jquery/1.11.0/jquery.min.js'></script>
# <script src='js/bootstrap.min.js'></script>
# <script type="text/javascript" src="js/bootstrap-select.js"></script>
# <script src="js/waypoints.js"></script>
# <script src="js/menu/modernizr.custom.js"></script>
# <script src="js/chart/echarts.js"></script>
# <script src="js/litebox.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--
# function MM_openBrWindow(theURL,winName,features) { //v2.0
#   window.open(theURL,winName,features);
# }
#
# function CS(){
#    var sub = document.form1.subject;
#    if(sub.value == "如何參與的問題")
#    	return confirm("由於報名踴躍，目前部份地區預約參與民眾較多，先前已透過電話或網路報名者，我們將依優先順序陸續與您連絡。尚未報名者，我們將會陸續開放報名，再次感謝您熱心的參與。");
# }
#
# //-->
# </script>
# </head>
# <body>
#   <div id="scroll_top"></div>
#   <nav id="navigation-menu" class="fixed">
#       <ul>
#           <li>
#           <a href="#scroll_top" class="mPS2id-clicked">
#               <div class="popover">
#                 <div class="arrow"></div>
#                 <div class="popover-title">TOP</div>
#               </div>
#           </a>
#           </li>
# 		  <li>
#               <a href="#scroll_other">
#                   <div class="popover">
#                     <div class="arrow"></div>
#                     <div class="popover-title">Biobanks Around The World</div>
#                   </div>
#               </a>
#           </li>
# 		  <li>
#               <a href="#scroll_info">
#                   <div class="popover">
#                     <div class="arrow"></div>
#                     <div class="popover-title">Purpose Of TAIWAN Biobank</div>
#                   </div>
#               </a>
#           </li>
# 		  <li>
#               <a href="#scroll_distribution">
#                   <div class="popover">
#                     <div class="arrow"></div>
#                     <div class="popover-title">The Distribution Of TWB Recruitment Centres</div>
#                   </div>
#               </a>
#           </li>
# 		  <!--li>
#               <a href="#scroll_cohort">
#                   <div class="popover">
#                     <div class="arrow"></div>
#                     <div class="popover-title">Who’s In The Cohort</div>
#                   </div>
#               </a>
#           </li>
# 		  <li>
#               <a href="#scroll_flow">
#                   <div class="popover">
#                     <div class="arrow"></div>
#                     <div class="popover-title">Participation program</div>
#                   </div>
#               </a>
#           </li-->
# 		  <li>
#               <a href="#scroll_characteristics">
#                   <div class="popover">
#                     <div class="arrow"></div>
#                     <div class="popover-title">Demographic Characteristics In Taiwan Biobank</div>
#                   </div>
#               </a>
#           </li>
# 		   <!--li>
#               <a href="#scroll_collected">
#                   <div class="popover">
#                     <div class="arrow"></div>
#                     <div class="popover-title">What Has Been Measured And Collected?</div>
#                   </div>
#               </a>
#           </li-->
#           <li>
#           <a href="#scroll_chart">
#               <div class="popover">
#                 <div class="arrow"></div>
#                 <div class="popover-title">Statistics</div>
#               </div>
#           </a>
#           </li>
#           <!--li>
#               <a href="#scroll_join">
#                   <div class="popover">
#                     <div class="arrow"></div>
#                     <div class="popover-title">我要參加</div>
#                   </div>
#               </a>
#           </li>
#           <li>
#               <a href="#scroll_contact">
#                   <div class="popover">
#                     <div class="arrow"></div>
#                     <div class="popover-title">聯絡我們</div>
#                   </div>
#               </a>
#           </li>
#           <li>
#               <a href="#scroll_partner">
#                   <div class="popover">
#                     <div class="arrow"></div>
#                     <div class="popover-title">合作夥伴</div>
#                   </div>
#               </a>
#           </li-->
#       </ul>
#   </nav>
#     <!--nav class="cbp-spmenu cbp-spmenu-vertical cbp-spmenu-left">
#         <div class="menuTitle"><img src="img/logo.svg"><a class="menu-left close"><i class="icon-cancel"></i></a></div>
#         <a href="index.php"><i class="icon-home"></i> 首頁</a>
#         <a href="about.html"><i class="icon-chart-bar"></i> 關於資料庫</a>
#         <a href="activity.php"><i class="icon-calendar"></i> 活動資訊</a>
#         <a href="about-export.html"><i class="icon-upload"></i> 資料庫釋出</a>
#         <a href="join-flow-before.html"><i class="icon-join"></i> 參加資訊(我要參加)</a>
#         <a href="download.html"><i class="icon-folder-open"></i> 檔案下載 </a>
#         <a href="faq.html"><i class="icon-chat"></i> Q & A</a>
#         <a href="contact.html"><i class="icon-location-1"></i> 聯絡我們</a>
# 	<a href="https://www.youtube.com/watch?v=tVIHlchyOCs" target="_self" class="litebox" data-litebox-group="group-2"><i class="icon-youtube-play"></i> 微電影</a>
#     </nav>
#     <nav class="main-nav cbp-spmenu cbp-spmenu-vertical">
#         <div class="logoarea"><a href="index.php"><img src="img/logo.svg"></a></div>
#         <a href="index.php"><i class="icon-home"></i> 首頁</a>
#         <a href="about.html"><i class="icon-chart-bar"></i> 關於資料庫</a>
#         <a href="activity.php"><i class="icon-calendar"></i> 活動資訊</a>
#         <a href="about-export.html"><i class="icon-upload"></i> 資料庫釋出</a>
#         <a href="join-flow-before.html"><i class="icon-join"></i> 參加資訊(我要參加)</a>
#         <a href="download.html"><i class="icon-folder-open"></i> 檔案下載 </a>
#         <a href="faq.html"><i class="icon-chat"></i> Q & A</a>
#         <a href="contact.html"><i class="icon-location-1"></i> 聯絡我們</a>
# 		<a href="https://www.youtube.com/watch?v=tVIHlchyOCs" target="_self" class="litebox" data-litebox-group="group-2"><i class="icon-youtube-play"></i> 微電影</a>
#     </nav-->
#
#
# <nav class="cbp-spmenu cbp-spmenu-vertical cbp-spmenu-left">
#         <div class="menuTitle"><img src="img/logo.svg"><a class="menu-left close"><i class="icon-cancel"></i></a></div>
#         <a href="../new_web/index.php"><i class="icon-home"></i> 中文版</a>
# 		<a href="index.php"><i class="icon-home"></i> Home</a>
# 		<a href="join-flow-before.php"><i class="icon-users"></i> Cohort</a>
# 		<a href="join-disease.php"><i class="icon-users"></i> Disease</a>
# 		<a href="about-export.php"><i class="icon-upload"></i> Data Access</a>
#         <!--a href="news.php"><i class="icon-chat"></i> 最新消息</a>
#         <a href="about.php"><i class="icon-chart-bar"></i> 關於資料庫</a>
#         <a href="activity.php"><i class="icon-calendar"></i> 活動資訊</a>
#         <a href="about-export.php"><i class="icon-upload"></i> 資料庫釋出</a>
#         <a href="join-flow-before.php"><i class="icon-join"></i> 參加資訊(我要參加)</a>
#         <a href="download.php"><i class="icon-folder-open"></i> 檔案下載 </a>
#         <a href="faq.php"><i class="icon-chat"></i> Q & A</a>
#         <a href="contact.php"><i class="icon-location-1"></i> 聯絡我們</a>
# 	<a href="mv-4.php?year=105"><i class="icon-youtube-play"></i> 影片欣賞</a>
#         <a href="media-3.php?year=105"><i class="icon-edit"></i> 媒體報導</a-->
#     </nav>
#     <nav class="main-nav cbp-spmenu cbp-spmenu-vertical">
#         <div class="logoarea"><a href="index.php"><img src="img/logo.svg"></a></div>
#         <a href="../new_web/index.php"><i class="icon-home"></i> 中文版</a>
# 		<a href="index.php"><i class="icon-home"></i> Home</a>
# 		<a href="join-flow-before.php"><i class="icon-users"></i> Cohort</a>
# 		<a href="join-disease.php"><i class="icon-users"></i> Disease</a>
# 		<a href="about-export.php"><i class="icon-upload"></i> Data Access</a>
#         <!--a href="news.php"><i class="icon-chat"></i> 最新消息</a>
#         <a href="about.php"><i class="icon-chart-bar"></i> 關於資料庫</a>
#         <a href="activity.php"><i class="icon-calendar"></i> 活動資訊</a>
#         <a href="about-export.php"><i class="icon-upload"></i> 資料庫釋出</a>
#         <a href="join-flow-before.php"><i class="icon-join"></i> 參加資訊(我要參加)</a>
#         <a href="download.php"><i class="icon-folder-open"></i> 檔案下載 </a>
#         <a href="faq.php"><i class="icon-chat"></i> Q & A</a>
#         <a href="contact.php"><i class="icon-location-1"></i> 聯絡我們</a>
# 	<a href="mv-4.php?year=105"><i class="icon-youtube-play"></i> 影片欣賞</a>
#         <a href="media-3.php?year=105"><i class="icon-edit"></i> 媒體報導</a-->
#     </nav>
#
# 	<div class="scroller-inner main">
#         <div class="changeTopbar">
#             <li><a href="index.php"><img src="img/logo.svg"></a></li>
#             <li class="menu"><a class="toggle-menu menu-left"></a></li>
#             <!--li class="gojoin"><a href="index.php#scroll_join"><i class="icon-join"></i>我要參加</a></li-->
#         </div>
#         <div id="main">
#             <section class="mina_visual" id="scroll_home"><BR><BR><BR><BR><BR><BR><BR><BR>
#
# 			<!--iframe width="560" height="315" src="https://www.youtube.com/v/tVIHlchyOCs&autoplay=1&loop=1" frameborder="1" allowfullscreen></iframe-->
#
#                 <div class="statistics">
#             	<div class="logoarea_rwd"><a href="index.php"><img src="img/logo.svg"></a></div>
#                   <ul>
#                     <li><h2>The Cumulative</h2><h3>Cumulative Total</h3></li>
#                                         <li><font size="5"><strong>Community Based</strong></font></li>
#
#                         <li><h4>118,548<span>cases received</span></h4></li>
#                         <li><h4>24,936<span>follow-up cases</span></h4></li>
#                                         <p><li><font size="5"><strong>Hospital Based</strong></font></li>
#                         <li><h4>3,145<span>cases received</span></h4></li>
#                         <li><h4>659<span>follow-up cases</span></h4></li>
#                         <li><h4>104<span>Second round follow-up cases</span></h4></li><li></li>
#                         <li><h8><span>As of 31 July, 2019</span></h8></li>
#
#                         </p>
#
#                   </ul>
#                 </div>
#                 <div class="gotoNext"><p>Scroll Down</p><a href="#" rel="next"></a></div>
#             </section>
#
# 			<section id="scroll_other" class="otherCountry">
#             	<div class="container" style="width:900px">
#                         <div class="title col-xs-10 col-xs-offset-1 col-lg-8 col-lg-offset-2">
#                             <h3>Biobanks Around The World</h3>
#                             <p align="left">
# 							The population of each country is unique with respect to genes, lifestyle, and other risk factors. That is why more and more countries have established their own biobanks. For example, Iceland, the UK, Japan, Estonia, the United States, Germany, Canada, etc., have already established their own biobanks.
#                             </p>
#                         </div>
#                         <div class="col-xs-12">
#                             <div class="countryArea">
#                                 <div class="countryItem" style="right: 120px;top: 180px;">
#                                     <span class="tooltipbb tooltipbb-effect-1">
#                                         <div class="tooltipbb-item"></div>
#                                         <span class="tooltipbb-content clearfix">
#                                             <span class="tooltipbb-text">
#                                                 <div class="country-flag"><img src="img/country-japan.svg"></div>
#                                                 <a href="http://www.biobankjp.org/" target="_blank">
#                                                 	<h5>日本<br>BioBank Japan</h5>
#                                                 	<p>2003-2017<br>300,000 Pts</p>
#                                                 </a>
#                                             </span>
#                                         </span>
#                                     </span>
#                                 </div><!-- countryItem end  -->
#                                 <div class="countryItem" style="left:420px; top:73px;">
#                                     <span class="tooltipbb tooltipbb-effect-1">
#                                         <div class="tooltipbb-item"></div>
#                                         <span class="tooltipbb-content clearfix">
#                                             <span class="tooltipbb-text">
#                                                 <div class="country-flag"><img src="img/country-sweden.svg"></div>
#                                                 	<h5>瑞典<br>The Swedish National Biobank Program </h5>
#                                                 	<p>2002-2004<br>185,000 sampling occasionsn</p>
#                                                 </a>
#                                             </span>
#                                         </span>
#                                     </span>
#                                 </div><!-- countryItem end  -->
#                                 <div class="countryItem" style="left:435px; top:115px;">
#                                     <span class="tooltipbb tooltipbb-effect-1">
#                                         <div class="tooltipbb-item"></div>
#                                         <span class="tooltipbb-content clearfix">
#                                             <span class="tooltipbb-text">
#                                                 <div class="country-flag"><img src="img/country-eesti.svg"></div>
#                                                 <a href="http://www.geenivaramu.ee/en/" target="_blank">
#                                                 	<h5>愛沙尼亞<br>The Estonian Gene Bank</h5>
#                                                 	<p>2000-present<br>52,000 participants</p>
#                                                 </a>
#                                             </span>
#                                         </span>
#                                     </span>
#                                 </div><!-- countryItem end  -->
#                                 <div class="countryItem" style="left:400px; top:83px;">
#                                     <span class="tooltipbb tooltipbb-effect-1">
#                                         <div class="tooltipbb-item"></div>
#                                         <span class="tooltipbb-content clearfix">
#                                             <span class="tooltipbb-text">
#                                                 <div class="country-flag"><img src="img/country-norway.svg"></div>
#                                                 <a href="http://www.kreftregisteret.no/en/" target="_blank">
#                                                 	<h5>挪威<br>Janus Serum Bank in Norway (The JANUS project)</h5>
#                                                 	<p>1973- present<br>317,000 donors</p>
#                                                 </a>
#                                             </span>
#                                         </span>
#                                     </span>
#                                 </div><!-- countryItem end  -->
#                                 <div class="countryItem" style="left:400px; top:110px;">
#                                     <span class="tooltipbb tooltipbb-effect-1">
#                                         <div class="tooltipbb-item"></div>
#                                         <span class="tooltipbb-content clearfix">
#                                             <span class="tooltipbb-text">
#                                                 <div class="country-flag"><img src="img/country-danmark.svg"></div>
#                                                 <a href="http://www.biobankdenmark.dk/" target="_blank"></a>
#                                                 	<h5>丹麥<br>Danish National Biobank</h5>
#                                                 	<p>1982<br>More than 15 million blood and tissue samples have been collected.</p>
#                                                 </a>
#                                             </span>
#                                         </span>
#                                     </span>
#                                 </div><!-- countryItem end  -->
#                                 <div class="countryItem" style="left:370px; top:101px;">
#                                     <span class="tooltipbb tooltipbb-effect-1">
#                                         <div class="tooltipbb-item"></div>
#                                         <span class="tooltipbb-content clearfix">
#                                             <span class="tooltipbb-text">
#                                                 <div class="country-flag"><img src="img/country-uk.svg"></div>
#                                                 <a href="http://www.ukbiobank.ac.uk/" target="_blank">
#                                                 <h5>英國<br>UK Biobank</h5>
#                                                 <p>2006-2010<br>500,000 participants</p>
#                                                 </a>
#                                             </span>
#                                         </span>
#                                     </span>
#                                 </div><!-- countryItem end  -->
#                                 <div class="countryItem" style="left:410px; top:130px;">
#                                     <span class="tooltipbb tooltipbb-effect-1">
#                                         <div class="tooltipbb-item"></div>
#                                         <span class="tooltipbb-content clearfix">
#                                             <span class="tooltipbb-text">
#                                                 <div class="country-flag"><img src="img/country-germany.svg"></div>
#                                                 <a href="http://www.nationale-kohorte.de/" target="_blank">
#                                                 	<h5>德國<br>The German National Cohort</h5>
#                                                 	<p>2014- present<br>200,000 participants</p>
#                                                 </a>
#                                             </span>
#                                         </span>
#                                     </span>
#                                 </div><!-- countryItem end  -->
#                                 <div class="countryItem" style="right:135px; top:155px;">
#                                     <span class="tooltipbb tooltipbb-effect-1">
#                                         <div class="tooltipbb-item"></div>
#                                         <span class="tooltipbb-content clearfix">
#                                             <span class="tooltipbb-text">
#                                                 <div class="country-flag"><img src="img/country-korea.svg"></div>
#                                                 	<h5>韓國<br>National Biobank of Korea</h5>
#                                                 	<p></p>
#                                                     <p>2008-2012<br>525,416 participants</p>
#                                                 </a>
#                                             </span>
#                                         </span>
#                                     </span>
#                                 </div><!-- countryItem end  -->
#                                 <div class="countryItem" style="right:200px; top:250px;">
#                                     <span class="tooltipbb tooltipbb-effect-1">
#                                         <div class="tooltipbb-item"></div>
#                                         <span class="tooltipbb-content clearfix">
#                                             <span class="tooltipbb-text">
#                                                 <div class="country-flag"><img src="img/country-malaysia.svg"></div>
#                                                 <h5>馬來西亞<br>The Malaysian Cohort</h5>
#                                                 <p>2005- present<br>106,527participants</p>
#                                                 </a>
#                                             </span>
#                                         </span>
#                                     </span>
#                                 </div><!-- countryItem end  -->
#                                 <div class="countryItem" style="left:180px; top:170px;">
#                                     <span class="tooltipbb tooltipbb-effect-1">
#                                         <div class="tooltipbb-item"></div>
#                                         <span class="tooltipbb-content clearfix">
#                                             <span class="tooltipbb-text">
#                                                 <div class="country-flag"><img src="img/country-us.svg"></div>
#                                                 <a href="http://www.framinghamheartstudy.org/" target="_blank">
#                                                 	<h5>美國<br>The Framingham Heart Study (the oldest biobank)</h5>
#                                                 	<p>1948- present<br>15,000 participants (three generations)</p>
#                                                 </a>
#                                             </span>
#                                         </span>
#                                     </span>
#                                 </div><!-- countryItem end  -->
#                                 <div class="countryItem" style="left:140px; top:190px;">
#                                     <span class="tooltipbb tooltipbb-effect-1">
#                                         <div class="tooltipbb-item"></div>
#                                         <span class="tooltipbb-content clearfix">
#                                             <span class="tooltipbb-text">
#                                                 <div class="country-flag"><img src="img/country-mexiko.svg"></div>
#                                                 	<h5>墨西哥<br>The Mexico City Prospective Study</h5>
#                                                 	<p>1998-2004<br>150,000 adults</p>
#                                                 </a>
#                                             </span>
#                                         </span>
#                                     </span>
#                                 </div><!-- countryItem end  -->
#                                 <div class="countryItem" style="right:175px; top:170px;">
#                                     <span class="tooltipbb tooltipbb-effect-1">
#                                         <div class="tooltipbb-item"></div>
#                                         <span class="tooltipbb-content clearfix">
#                                             <span class="tooltipbb-text">
#                                                 <div class="country-flag"><img src="img/country-china.svg"></div>
#                                                 <a href="http://www.ckbiobank.org/site/" target="_blank">
#                                                 	<h5>中國<br>China Kadoorie Biobank</h5>
#                                                 	<p>2004-2008<br>512,891 adults</p>
#                                                 </a>
#                                             </span>
#                                         </span>
#                                     </span>
#                                 </div><!-- countryItem end  -->
#                                 <div class="countryItem" style="right:180px; top:150px;">
#                                     <span class="tooltipbb tooltipbb-effect-1">
#                                         <div class="tooltipbb-item"></div>
#                                         <span class="tooltipbb-content clearfix">
#                                             <span class="tooltipbb-text">
#                                                 <div class="country-flag"><img src="img/country-china.svg"></div>
#                                                 <a href="http://nationalgenebank.org/" target="_blank">
#                                                 	<h5>中國<br>The China National Genebank (under construction) </h5>
#                                                 	<p>(under construction) <br>30 million samples</p>
#                                                 </a>
#                                             </span>
#                                         </span>
#                                     </span>
#                                 </div><!-- countryItem end  -->
#                                 <div class="countryItem" style="left:382px; top:131px;">
#                                     <span class="tooltipbb tooltipbb-effect-1">
#                                         <div class="tooltipbb-item"></div>
#                                         <span class="tooltipbb-content clearfix">
#                                             <span class="tooltipbb-text">
#                                                 <div class="country-flag"><img src="img/country-dutch.svg"></div>
#                                                 	<h5>荷蘭<br>Lifelines Cohort (Dutch population-based cohort study)</h5>
#                                                 	<p>2004-present<br>167,792 participants</p>
#                                                 </a>
#                                             </span>
#                                         </span>
#                                     </span>
#                                 </div><!-- countryItem end  -->
#                                 <div class="countryItem" style="right:325px; top:210px;">
#                                     <span class="tooltipbb tooltipbb-effect-1">
#                                         <div class="tooltipbb-item"></div>
#                                         <span class="tooltipbb-content clearfix">
#                                             <span class="tooltipbb-text">
#                                                 <div class="country-flag"><img src="img/country-saudi.svg"></div>
#                                                 <a href="http://kaimrc.med.sa/index.php?option=com_content&view=article&id=31&Itemid=28&lang=en" target="_blank">
#                                                 	<h5>沙烏地阿拉伯<br>Saudi Biobanking Project</h5>
#                                                 	<p>(under construction)<br>200,000 people </p>
#                                                 </a>
#                                             </span>
#                                         </span>
#                                     </span>
#                                 </div><!-- countryItem end  -->
#                                 <div class="countryItem" style="right:255px; top:220px;">
#                                     <span class="tooltipbb tooltipbb-effect-1">
#                                         <div class="tooltipbb-item"></div>
#                                         <span class="tooltipbb-content clearfix">
#                                             <span class="tooltipbb-text">
#                                                 <div class="country-flag"><img src="img/country-india.svg"></div>
#                                                 	<h5>印度<br>ICMR National Tumour Tissue Repository (INTTR, Tumour Tissue Repository in India)</h5>
#                                                 	<p>2005- present<br>27,342 cases</p>
#                                                 </a>
#                                             </span>
#                                         </span>
#                                     </span>
#                                 </div><!-- countryItem end  -->
#                             </div><!-- countryArea end  -->
#                             <div class="countryImg"><img src="img/map.png"></div>
#                         </div><!--  col-xs-12 end  -->
#             	</div>
#             </section>
#
# 			<section id="scroll_info">
#                 <div class="container">
#                     <div class="row">
#                         <div class="title col-xs-12 col-lg-8 col-lg-offset-2">
#                             <h3>Purpose Of Taiwan Biobank</h3>
#                             <div role="tabpanel">
#                               <!-- Tab panes -->
#                               <div class="tab-content">
#                                 <div role="tabpanel" class="tab-pane fade in active" id="A">
# 								With the advances in medicine, Taiwan has resulted in an aging population and longer average life expectancy. As such, health promotion and chronic disease prevention have become important public health issues. In addition, chronic diseases like cancer, heart disease, cerebrovascular disease, diabetes, chronic hepatitis, liver cirrhosis, hypertension, and so on, are all among the top ten causes of death in Taiwan. Hence, the prevention of chronic disease has become a primary task for the government. If we can gain a more understanding of people’s lifestyles and health risk factors, find the causes of common diseases, and attempt to change lifestyle choices that affect people’s health, the health of our nation will improve, and the incidence of chronic disease may be ameliorated. By combining genetic and medical information, Taiwan Biobank intends to conduct large-scale cohort studies and case-control studies on local diseases. The cohort study will call for 200,000 volunteers, while the case-control study will invite 100,000 patients with the 10 to 15 most common diseases. These studies will enable Taiwan Biobank to identify the disease-causing factors and mechanisms of common diseases to facilitate the development of better treatment and prevention, reduce the cost of medical treatment and make it possible to achieve the goal of improving our nation’s health. Therefore, the establishment of Taiwan Biobank will not only help to identify disease-causing factors and mechanisms, but will also provide a huge resource for biomedical research, thus avoiding the difficulties encountered in the past in studying the relationship between genes and environmental factors.
#
#                                 </div>
# 								<img src="img/imgpsh_fullsize.png">
#                                 <div role="tabpanel" class="tab-pane fade" id="B">
#
#
#                                 • 建立符合人體生物資料庫管理條例之典範資料庫。<br>
#                                 • 成立多中心的資料收集合作聯盟。<br>
#                                 • 建立具有連續性資料收集的資料庫，透過追蹤方式，更新參與個案生活習慣變化、健<br>&nbsp;&nbsp;&nbsp;康狀況、臨床治療/用藥資訊、病程進展與生物檢體等。<br>
#                                 • 提供國內研究者生物檢體與臨床資料，以進行生物醫學領域相關研究。<br>
#                                 </div>
#                               </div>
#
#                               <!-- Nav tabs -->
#                               <!--ul class="nav nav-tabs" role="tablist">
#                                 <li role="presentation" class="active">
#                                     <a href="#A" aria-controls="home" role="tab" data-toggle="tab">源起</a>
#                                 </li>
#                                 <li role="presentation">
#                                     <a href="#B" aria-controls="profile" role="tab" data-toggle="tab">籌設目的</a>
#                                 </li>
#                                 <li role="presentation"><a href="about.php">了解更多</a></li>
#                               </ul-->
#                             </div>
#                         </div>
#                     </div>
#                 </div>
#             </section>
#
# 			<section id="scroll_distribution">
#                 <div class="container">
#                     <div class="row">
#                         <!--div class="title col-xs-12 col-md-10 col-md-offset-1 col-lg-8 col-lg-offset-2"-->
#                         <div class="title col-xs-12 col-md-10 col-md-offset-1 col-lg-8 col-lg-offset-2">
#                             <h3>The Distribution Of TWB Recruitment Centres</h3>
#                         </div>
#                         <div class="col-xs-12">
#                             <p>
# 								The distribution of all 29 TWB recruitment centres and the population density of Taiwan. The colours represent the population density (persons per km²) of each city or county. There is at least one recruitment centre in each city or county.
#                             </p>
#                             <center><img src="img/distribution.jpg" width="500"></img></center>
#                         </div>
#                             <div class="col-xs-12 col-sm-8 col-sm-offset-2">
#                             <!--a class="btn btn-primary" href="join-flow-before.php">了解更多</a-->
#                             </div>
#                     </div>
#                 </div>
#             </section>
#
# 			<!--section id="scroll_cohort">
#                 <div class="container">
#                     <div class="row">
#                         <div class="title col-xs-12 col-md-10 col-md-offset-1 col-lg-8 col-lg-offset-2">
#                             <h3>Who’s in the cohort?</h3>
#                         </div>
#                         <div class="col-xs-12">
#                             <p>
# 							The TWB plans to conduct both a large-scale community-based cohort and several patient cohorts on local chronic diseases from medical centres (the hospital-based cohorts). The community-based cohort study will recruit 200,000 volunteers between 30 and 70 years of age with no history of cancer, and the hospital-based cohort study will recruit 100,000 patients affected by the most common chronic diseases in Taiwan, including lung, breast, oral activity and colorectal cancers, hepatitis, cardiovascular disease, diabetes, chronic kidney disease, stroke, Alzheimer’s disease, endometriosis, and asthma. In this report we describe the progress of the community-based cohort study of the TWB.
#                             </p>
#                         </div>
#                         <div class="col-xs-12 col-sm-8 col-sm-offset-2">
#                         </div>
#                     </div>
#                 </div>
#             </section-->
#
# 			<!--section id="scroll_flow">
#                 <div class="container">
#                     <div class="row">
#                         <div class="title col-xs-12 col-md-10 col-md-offset-1 col-lg-8 col-lg-offset-2">
#                             <h3>Participation program</h3>
#                         </div>
#                         <div class="flowList">
#                             <ul>
#                                 <li><h6>Step 1</h6><a><img src="img/flow/expand.svg"></a><h5>Recruitment</h5></li>
#                                 <li><h6>Step 3</h6><a><img src="img/flow/agree.svg"></a><h5>Informed Consent</h5></li>
#                                 <li><h6>Step 5</h6><a><img src="img/flow/science.svg"></a><h5>Biospecimen Collection</h5></li>
#                                 <li><h6>Step 7</h6><a><img src="img/flow/rating.svg"></a><h5>Feedback Survey</h5></li>
#                             </ul>
#                             <ul>
#                                 <li><h6>Step 2</h6><a><img src="img/flow/phone.svg"></a><h5>Reservation</h5></li>
#                                 <li><h6>Step 4</h6><a><img src="img/flow/measure.svg"></a><h5>Physical Examination</h5></li>
#                                 <li><h6>Step 6</h6><a><img src="img/flow/questionnaire.svg"></a><h5>Questionnaire</h5></li>
#                                 <li><h6>Step 8</h6><a><img src="img/flow/ok.svg"></a><h5>Biospecimen and Data Storage</h5></li>
#                             </ul>
#                         </div>
#                             <div class="col-xs-12 col-sm-8 col-sm-offset-2">
#                             </div>
#                     </div>
#                 </div>
#             </section-->
#
# 			<!--section id="scroll_collected">
#                 <div class="container">
#                     <div class="row">
#                         <div class="title col-xs-12 col-md-10 col-md-offset-1 col-lg-8 col-lg-offset-2">
#                             <h3>What has been measured and collected?</h3>
#                         </div>
#                         <div class="col-xs-12">
#                             <p align="left">
# 							After confirmation of their eligibility and the provision of informed consent, participants attend a baseline enrolment visit at their local recruitment centre. The biospecimen/ information collection include:
# 							<ol align="left">
# 							<li>1.comprehensive questionnaire<br>The questionnaire obtains basic personal information and information on lifestyle, dietary habits, environmental exposure, reproductive history, medical history, and family disease history.
# 							<li>2.physical examination<br>The physical examination includes measurement of height, weight, body fat, waist and hip circumference, blood pressure, heart rate, bone mass density of tibia, and pulmonary function.
# 							<li>3.Blood and urine samples<br>A 30-mL blood sample and 15-mL urine sample are taken from each participant. Urine samples are sent to the TWB central laboratory for microalbumin analysis and then divided into two portions to be stored at -80°C and -196°C. A portion of each blood sample is processed into serum and sent to the TWB central laboratory for haematological and biochemical analysis, and the remainder is stored as plasma at both -80°C and -196°C (in liquid nitrogen), and is extracted for DNAs then stored at 4°C. The haematological and biochemical analysis quantifies red blood cells, white blood cells, platelets, haemoglobin, haematocrit, fasting glucose, glycated haemoglobin, total cholesterol, albumin creatinine, triglyceride, high-density lipoprotein, low-density lipoprotein, total bilirubin, serum glutamic oxaloacetic transaminase, serum glutamic-pyruvic transaminase, γ-glutamyl transferase, α-foetal protein, blood urea nitrogen, uric acid, anti-hepatitis C virus antibody (HCV Ab), hepatitis B virus surface antigen (HBsAg), anti-hepatitis B surface-antigen antibody (HBsAb), anti-hepatitis B virus core-antigen antibody (HBcAb), and hepatitis B virus e antigen (HBeAg).
# 							<li>4.whole genome genotyping
# 							<li>5.whole genome sequence
# 							<li>6.DNA methylation
# 							<li>7.EKG, Abdominal echo, Carotid ultrasound, thyroid hormones (follow-ups)
# 							<li>8.plasticizer and melamine detections
# 							</ol>
#                             </p>
#                         </div>
#                         <div class="col-xs-12 col-sm-8 col-sm-offset-2">
#                         </div>
#                     </div>
#                 </div>
#             </section-->
#
# 			<section id="scroll_characteristics">
#                 <div class="container">
#                     <div class="row">
#                         <!--div class="title col-xs-12 col-md-10 col-md-offset-1 col-lg-8 col-lg-offset-2"-->
#                         <div class="title col-xs-12 col-md-10 col-md-offset-1 col-lg-8 col-lg-offset-2">
#                             <h3>Demographic Characteristics in Taiwan Biobank (as of June 30, 2019)</h3>
#                         </div>
#                         <div class="col-sm-12 col-md-6 chartItem">
#                         	<div class="title">Gender Distribution</div>
#                             <div class="subtitle">The gender ratio of Male: Female is about 1:1.8 among 101,567 participants.</div>
#                             <div id="chart-gender" style="height:500px;"></div>
#                         </div>
#                     	<div class="col-sm-12 col-md-6 chartItem">
#                         	<div class="title">Age Distribution</div>
#                             <div class="subtitle"></div>
#                             <div id="chart-year" style="height:500px;"></div>
#                         </div>
#                         <div class="col-xs-12 col-sm-8 col-sm-offset-2">
#                         </div>
#                     </div>
#                 </div>
#             </section>
#
#
#             <section class="chartArea" id="scroll_chart">
#             	<div class="container">
#                     <!--div class="row">
#                         <div class="col-xs-12 col-md-5 description">
#                                 <h3>Top ten causes of death in Taiwan</h3>
#                                 <p>
#                                  近來臺灣社會進步，經濟富裕，醫療水準提升，臺灣地區人口結構趨於老化、國人壽命延長，慢性疾病已經取代過去的傳染病成為現在重要的公共衛生議題。根據衛生福利部統計，國人十大死因為：惡性腫瘤、腦血管疾病、心臟病、糖尿病、事故傷害、慢性肝病及肝硬化等等，因此慢性疾病之預防與保健也成為改善國人健康的首要目標。
#                                 </p>
#                                 <a class="more" href="about-chart.php">更多數據</a>
#                         </div>
#                         <div class="col-sm-12 col-md-7 chart">
#                             <div id="chart-tenDead" style="height:500px;"></div>
#                         </div>
#                     </div--><!--  row end  -->
#                     <div class="row">
#                         <div class="col-xs-12 col-md-7 chart">
#                             <div id="chart-A" style="height:450px;"></div>
#                         </div>
#                         <div class="col-xs-12 col-md-5 description ">
#                             <div class="col-xs-12">
#                                 <h3>Family History of Cancers<br><!--cancer family syndrome--></h3>
#                                 <p>
#                                 The distributions of Taiwan Biobank participants with at least one relative (birth parent or sibling) who had been diagnosed with cancer. Liver cancer was the most common cancer (9.25%).
#                                 </p>
#                                 <!--a class="more" href="about-chart.php">更多數據</a-->
#                             </div>
#                         </div>
#                     </div><!--  row end  -->
#                     <div class="row">
#                         <div class="col-xs-12 chart animateblock">
# 						 <div class="title col-xs-12 col-md-10 col-md-offset-1 col-lg-8 col-lg-offset-2">
# 						<h3>Prevalence of Leading Causes of Self-Reported Diseases in TWB Participants<br><!--cancer family syndrome--></h3>
# 						</div>
#                             <div id="chart-cardiovascular" style="height:600px;"></div>
#                         </div>
#                         <!--div class="col-xs-12 description">
#                             <div class="col-xs-12 col-md-8 col-md-offset-2">
#                                 <h3>心血管疾病分佈<br></h3>
#                                 <p>
#                                 上圖為個案罹患藥物過敏、骨科或關節炎疾病、肺部呼吸道與心血管疾病等四大類疾病分布情形。排除回答不知道確診病名之個案，統計樣本依序為101,090人、101,023人、101,224人及100,831人。由於個案罹患心肌症、先天性心臟病與其他心臟病等疾病的比率較低，故此三種疾病合併至其他心臟病項下。
#                                 </p>
#
#                             </div>
#                         </div-->
#                         <br>
#                     </div><!--  row end  -->
#             	</div>
#             </section>
#             <!--section id="scroll_join">
#                 <div class="container">
#                     <div class="row">
#                         <div class="title col-xs-12 col-sm-8 col-sm-offset-2">
#                             <h3>我要參加</h3>
#                             <p align="left">年齡在30至70歲之間，具行為能力的民眾，不限性別，共計招募200,000名自願者參與。
#                             ※排除條件：不具本國籍或經醫生確診罹患癌症者。<br>
#                             </p>
# 							<p align="left">感謝民眾踴躍參與，由於目前部份地區預約參與民眾較多，因此先前已透過電話或網路報名者，我們將依優先順序陸續與您連絡。尚未報名者，我們將陸續開放報名，詳細接受電話與網路報名駐站如下表，而目前暫不開放報名之駐站，可透過參加各縣市之推廣活動，並現場填邀請單交予工作人員，再次感謝您的熱情參與。</p>
#
#
# 						<table border="1" cellspacing="0" cellpadding="0" align="center" width="90%">
# 									    <tbody>
# 										<tr>
# 									    <td>地區</td>
# 									    <td valign="top">駐站名稱<br /></td>
# 									    <td valign="top">報名情形</td>
# 									    <td valign="top">報名方式</td>
# 									    </tr>
# 										<tr>
# 									    <td>台北</td>
# 									    <td valign="top">三總汀州院區<br /></td>
# 									    <td valign="top">目前暫不開放</td>
# 									    <td valign="top"></td>
# 									    </tr>
# 										<tr>
# 									    <td rowspan="2">新北</td>
# 									    <td valign="top">衛福部雙和醫院<br /></td>
# 									    <td valign="top">預約報名中</td>
# 									    <td valign="top">02-22460785或官網</td>
# 									    </tr>
# 										<tr>
# 										<td valign="top">輔大診所</td>
# 									    <td valign="top">預約報名中<br /></td>
# 									    <td valign="top">02-29042172或官網</td>
# 									    </tr>
# 										<tr>
# 									    <td>桃園</td>
# 									    <td valign="top">衛福部桃園醫院<br /></td>
# 									    <td valign="top">目前暫不開放</td>
# 									    <td valign="top"></td>
# 									    </tr>
# 										<tr>
# 									    <td>新竹</td>
# 									    <td valign="top">台大新竹分院<br /></td>
# 									    <td valign="top">目前暫不開放</td>
# 									    <td valign="top"></td>
# 									    </tr>
# 										<tr>
# 										<td>苗栗</td>
# 									    <td valign="top">衛福部苗栗醫院<br /></td>
# 									    <td valign="top">預約報名中</td>
# 									    <td valign="top">037-266500或官網</td>
# 									    </tr>
# 										<tr>
# 									    <td rowspan="3">台中</td>
# 									    <td valign="top">衛福部豐原醫院<br /></td>
# 									    <td valign="top">預約報名中</td>
# 									    <td valign="top">04-25297697或官網</td>
# 									    </tr>
# 										<tr>
# 									    <td valign="top">中港澄清醫院<br /></td>
# 									    <td valign="top">預約報名中</td>
# 									    <td valign="top">04-24637802或官網</td>
# 									    </tr>
# 										<tr>
# 									    <td valign="top">中國醫藥大學附設醫院<br /></td>
# 									    <td valign="top">預約報名中</td>
# 									    <td valign="top">04-22029823</td>
# 									    </tr>
# 										<tr>
# 									    <td rowspan="2">彰化</td>
# 									    <td valign="top">彰濱秀傳醫院<br /></td>
# 									    <td valign="top">目前暫不開放</td>
# 									    <td valign="top"></td>
# 									    </tr>
# 										<tr>
# 									    <td valign="top">員林基督教醫院<br /></td>
# 									    <td valign="top">預約報名中</td>
# 									    <td valign="top">04-8393500或官網</td>
# 									    </tr>
# 										<tr>
# 									    <td>南投</td>
# 									    <td valign="top">埔里基督教醫院<br /></td>
# 									    <td valign="top">預約報名中</td>
# 									    <td valign="top">官網</td>
# 									    </tr>
# 										<tr>
# 									    <td rowspan="4">嘉義</td>
# 									    <td valign="top">衛福部朴子醫院<br /></td>
# 									    <td valign="top">目前暫不開放</td>
# 									    <td valign="top"></td>
# 									    </tr>
# 										<tr>
# 									    <td valign="top">大林慈濟醫院<br /></td>
# 									    <td valign="top">目前暫不開放</td>
# 									    <td valign="top"></td>
# 									    </tr>
# 										<tr>
# 									    <td valign="top">嘉義基督教醫院<br /></td>
# 									    <td valign="top">目前暫不開放</td>
# 									    <td valign="top"></td>
# 									    </tr>
# 										<tr>
# 									    <td valign="top">衛福部嘉義醫院<br /></td>
# 									    <td valign="top">目前暫不開放</td>
# 									    <td valign="top"></td>
# 									    </tr>
# 										<tr>
# 										<td rowspan="3">台南</td>
# 									    <td valign="top">柳營奇美醫院<br /></td>
# 									    <td valign="top">預約報名中</td>
# 									    <td valign="top">06-6224903或官網</td>
# 									    </tr>
# 										<tr>
# 									    <td valign="top">衛福部新營醫院<br /></td>
# 									    <td valign="top">目前暫不開放</td>
# 									    <td valign="top"></td>
# 									    </tr>
# 										<tr>
# ...
#                                     <input type="text" class="form-control" id="UserTel" name="UserTel" placeholder="手機 & 室內">
#                                   </div>
#                                   <div class="form-group col-xs-12 col-sm-6">
#                                     <label for="">駐點地區</label>
#                                   </div>
#                               </div>
#                               <div class="form-group">
#                                 <label for="">Email</label>
#                                 <input type="email" class="form-control" id="UserEmail" name="UserEmail" placeholder="電子信箱">
#                               </div>
#                               <div class="form-group">
#                                 <label for="">其他訊息</label>
#                                 <textarea class="form-control" rows="3" id="UserTxt" name="UserTxt"></textarea>
#                               </div>
#                               <div class="row">
#                                   <div class="form-group col-xs-12 btn-checkbox" data-toggle="buttons">
#                                     <label class="btn">
#                                         <input type="checkbox" autocomplete="off" id="agreee" name="agree" value="1">
#                                         <i class="icon-check"></i>
#                                     </label>
#
#                                         <span>我同意個人資料受到本計劃之<a href="#" onclick="myFunction()"><font color="red">【隱私權政策聲明】</font></a>之保護及規範。</span>
#
#                                   </div>
#                                   <div class="form-group col-xs-6 col-sm-3 verifyCode">
#                                     <label for="">驗證碼</label>
#                                     <p class="form-control-static">
# 					<input type="hidden" name="code0" id="code0" value="c4LIxf">c4LIxf				    </p>
#                                   </div>
#                                   <div class="form-group col-xs-6 col-sm-3">
#                                     <label for=""> &nbsp;</label>
#                                     <input type="text" class="form-control" id="code" name="code" placeholder="">
#                                   </div>
#                                   <div class="form-group col-xs-6 col-xs-offset-3 col-sm-3 col-sm-offset-3">
#                                     <label for=""> &nbsp;</label>
#                                     <button type="submit" class="form-control btn btn-primary">報名！</button>
#                                   </div>
#                               </div>
#                             </form>
#                         </div>
#                     </div>
#                 </div>
#             </section-->
#             <!--section class="contact" id="scroll_contact">
#             	<div class="container">
#                         <div class="title col-xs-12 ">
#                             <h3>聯絡我們</h3>
#                         </div>
#                         <div class="col-xs-12 col-sm-6  " style=" margin-bottom:30px;">
#                             <p>臺灣人體生物資料庫<br>
#                             臺北市南港區研究院路二段128號 中央研究院生物醫學科學研究所 9F<br>
#                             電話 / 02-2652-3580    傳真 / 02-2652-3583<br>
#                             E-mail：biobank@gate.sinica.edu.tw
#                             </p>
#                             <a href="contact.php" class="btn btn-primary" style="width:100%;"><i class="icon-location-1"></i> 研究駐站資訊</a>
#                         </div>
#                         <div class="col-xs-12 col-sm-6">
#                             <p>您的意見與建議將是本資料庫持續精進的方向。<br>
#                             歡迎您將意見或建議，透過電話、EMAIL或傳真與我們聯繫，請填寫下列表格，
#                             在收到您的意見或建議後，我們將會盡快回覆。</p>
#                             <form id="form1" name="form1" action="mail_con.php" method="post" onSubmit="return CS();">
#                               <div class="form-group">
#                                 <label for="">留言種類</label>
#                                 <select class="selectpicker" id="subject" name="subject">
#  					<option selected="selected" value="如何參與的問題">如何參與的問題</option>
# 			                <option value="網站問題">網站問題</option>
# 			                <option value="改善建議">改善建議</option>
# 					<option value="資料釋出相關問題">資料釋出相關問題</option>
#         			        <option value="其他">其他</option>
#                                 </select>
#                               </div>
#                               <div class="form-group">
#                                 <label for="">*姓名</label>
#                                 <input type="text" class="form-control" id="UserName" name="UserName" placeholder="">
#                               </div>
#                               <div class="row">
#                                   <div class="form-group col-xs-6" style="padding-left:15px;">
#                                     <label for="">*Email</label>
#                                     <input type="email" class="form-control" id="UserEmail" name="UserEmail" placeholder="電子信箱">
#                                   </div>
#                               </div>
#                               <div class="form-group">
#                                 <label for="">*意見或建議</label>
#                                 <textarea class="form-control" rows="3" id="UserTxt" name="UserTxt"></textarea>
#                               </div>
#                               <div class="row">
#                                   <div class="form-group col-xs-12 btn-checkbox" data-toggle="buttons">
#                                     <label class="btn">
#                                         <input type="checkbox" autocomplete="off" id="agree" name="agree" value="1">
#                                         <i class="icon-check"></i>
#                                     </label>
#                                         <span>
#                                         	我同意個人資料受到本計劃之<a href="#" onclick="myFunction()"><font color="red">【隱私權政策聲明】</font></a>之保護及規範。
#                                         </span>
#                                   </div>
#                                   <div class="form-group col-xs-6 col-sm-4 verifyCode">
#                                     <label for="">驗證碼</label>
#                                     <p class="form-control-static">
# 					<input type="hidden" name="code0" id="code0" value="JWkWBB">JWkWBB				     </p>
#                                   </div>
#                                   <div class="form-group col-xs-6 col-sm-4">
#                                     <label for=""> &nbsp;</label>
#                                     <input type="text" class="form-control" id="code" name="code" placeholder="">
#                                   </div>
#                                   <div class="form-group col-xs-6 col-xs-offset-3 col-sm-4 col-sm-offset-0">
#                                     <label for=""> &nbsp;</label>
#                                     <button type="submit" class="form-control btn btn-primary">送出</button>
#                                   </div>
#                               </div>
#                             </form>
#                         </div>
#             	</div>
#             </section-->
#             <!--section class="partner" id="scroll_partner">
#             	<div class="container">
#             		<div class="title col-xs-10 col-xs-offset-1">
#             			<h3>合作夥伴</h3>
#             		</div>
#                   <div class="title col-xs-12">
#                       <ul>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberA.jpg"><span>國際演說家-吳娟瑜</span></li>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberB.jpg"><span>台中市衛生局</span></li>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberC.jpg"><span>李偉文醫師</span></li>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberF.jpg"><span>台灣失智症協會</span></li>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberE.jpg"><span>中華民國失智者照顧協會</span></li>
# 						  <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberH.jpg"><span>三軍總醫院汀州院區</span></li>
#                       </ul>
#                   </div>
# 				  <div class="title col-xs-12">
# 				  <ul>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberI.jpg"><span>衛生福利部雙和醫院</span></li>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberJ.jpg"><span>衛生福利部桃園醫院</span></li>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberK.jpg"><span>台大醫院新竹分院</span></li>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberL.jpg"><span>衛生福利部苗栗醫院</span></li>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberM.jpg"><span>中港澄清醫院</span></li>
# 						  <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberN.jpg"><span>衛生福利部豐原醫院</span></li>
#                       </ul>
# 				  </div>
# 				  <div class="title col-xs-12">
# 				  <ul>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberO.jpg"><span>中國醫藥大學附設醫院</span></li>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberP.jpg"><span>彰濱秀傳醫院</span></li>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberQ.jpg"><span>彰化員生醫院</span></li>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberS.jpg"><span>埔里基督教醫院</span></li>
# 						  <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberT.jpg"><span>大林慈濟醫院</span></li>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberU.jpg"><span>嘉義基督教醫院</span></li>
#                       </ul>
# 				  </div>
# 				  <div class="title col-xs-12">
# 				  <ul>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberV.jpg"><span>衛生福利部朴子醫院</span></li>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberW.jpg"><span>衛生福利部新營醫院</span></li>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberX.jpg"><span>柳營奇美醫院</span></li>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberY.jpg"><span>臺南市立醫院</span></li>
# 						  <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberZ.jpg"><span>高雄市立大同醫院</span></li>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/member1.jpg"><span>高雄市立民生醫院</span></li>
#                       </ul>
# 				  </div>
# 				  <div class="title col-xs-12">
# 				  <ul>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/member2.jpg"><span>高雄義大醫院</span></li>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/member3.jpg"><span>衛生福利部屏東醫院</span></li>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/member4.jpg"><span>羅東聖母醫院</span></li>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/member5.jpg"><span>花蓮門諾醫院</span></li>
# 						  <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/member6.jpg"><span>衛生福利部臺東醫院</span></li>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberH.jpg"><span>三軍總醫院澎湖院區</span></li>
#                       </ul>
# 				  </div>
# 				  <div class="title col-xs-12">
# 				  <ul>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberfju.jpg"><span>輔大診所</span></li>
# 						  <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberW.jpg"><span>衛福部嘉義醫院</span></li>
# 						  <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberxg.jpg"><span>高雄市立小港醫院</span></li>
# 						  <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/memberH.jpg"><span>三軍總醫院內湖院區</span></li>
# 						  <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/member8.jpg"><span>中山醫學大學附設醫院</span></li>
# 						  <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/member7.jpg"><span>彰化基督教醫院</span></li>
#
#
#                       </ul>
# 				  </div>
# 				    <div class="title col-xs-12">
# 				  <ul>
# 						  <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/member9.jpg"><span>高雄醫學大學附設醫院</span></li>
#                           <li class="col-xs-6 col-sm-3 col-md-2"><img src="img/member10.jpg"><span>高雄榮民總醫院</span></li>
#                       </ul>
# 				  </div>
#             	</div>
#             </section-->
#        <!--footer>
#             <div class="container">
#                 <div class="col-xs-6 col-sm-3">
#                     <ul>
#                         <li><a href="about.html">關於資料庫</a></li>
#                         <li><a href="activity.php">活動資訊</a></li>
#                         <li><a href="about-export.html">資料庫釋出</a></li>
#                         <li><a href="download.html">檔案下載 </a></li>
#                         <li><a href="faq.html">Q & A</a></li>
#                         <li><a href="contact.php">聯絡我們</a></li>
#                     </ul>
#                 </div>
#                 <div class="col-xs-6 col-sm-3">
#                     <ul>
#                         <li><a href="about-chart.html">相關數據統計</a></li>
#                         <li><a href="join-flow-before.html">參加資訊(我要參加)</a></li>
#                         <li><a href="agree.html">隱私政策</a></li>
#                     </ul>
#                 </div>
#                 <div class="copyright col-sm-6">
#                     <div class="logo"><img src="img/logo_w.svg"></div>
#                     <p>Copyright  © 2015 臺灣人體生物資料庫 All rights reserved.</p>
#                 </div>
#             </div>
#         </footer-->
# 	<footer>
#             <div class="container">
#                 <div class="col-xs-6 col-sm-3">
#                     <ul>
#                         <!--li><a href="about.php">關於資料庫</a></li>
#                         <li><a href="activity.php">活動資訊</a></li>
#                         <li><a href="about-export.php">資料庫釋出</a></li>
#                         <li><a href="download.php">檔案下載 </a></li>
#                         <li><a href="faq.php">Q & A</a></li>
#                         <li><a href="contact.php">聯絡我們</a></li-->
#                     </ul>
#                 </div>
#                 <div class="col-xs-6 col-sm-3">
#                     <ul>
#                         <!--li><a href="about-chart.php">相關數據統計</a></li>
#                         <li><a href="join-flow-before.php">參加資訊(我要參加)</a></li>
#                         <li><a href="agree.php">隱私政策</a></li-->
#                     </ul>
#                 </div>
#                 <div class="copyright col-sm-6" align="right">
#                     <div class="logo"><img src="img/logo_w.svg"></div>
#                     <p>Copyright  © 2015 臺灣人體生物資料庫 All rights reserved.</p>
#                 </div>
#             </div>
#         </footer>
#
#     	</div><!-- /main -->
# </div><!-- /scroller-inner -->
#
# <script>
#     function myFunction() {
#     window.open("http://www.twbiobank.org.tw/new_web/agree.php", "_blank", "toolbar=yes, scrollbars=yes, resizable=yes, top=1000, left=500, width=900, height=800");
# }
# </script>
#
#
# <script src="js/chartdata-index.js"></script>
# <script src="js/custom-index.js"></script>
# <!-- Scroll To -->
# 	<script>
#       $(document).ready(function () {
#         var mySelect = $('#first-disabled2');
#
#         $('#special').on('click', function () {
#           mySelect.find('option:selected').attr('disabled', 'disabled');
#           mySelect.selectpicker('refresh');
#         });
#
#         var $basic2 = $('#basic2').selectpicker({
#           liveSearch: true,
#           maxOptions: 1
#         });
#       });
#     </script>
#     <script src="js/jquery.malihu.PageScroll2id.js"></script>
# <!-- Scroll To -->
# <script src="js/menu/jPushMenu.js"></script>
# <script type="text/javascript">
# 	$('.litebox').liteBox();
# </script>
#
# </body>
# </html>

# %%
import re
res = re.findall(r"<title>(.+?)</title>", html)
print("\nPage title is: ", res[0])
# Out:
# Page title is:  臺灣人體生物資料庫

# %%
res = re.findall(r'href="(http.*?)"', html)
print("\nAll http links: ", res)
# Out:
# All http links:  ['https://www.youtube.com/watch?v=tVIHlchyOCs', 'https://www.youtube.com/watch?v=tVIHlchyOCs', 'http://www.biobankjp.org/', 'http://www.geenivaramu.ee/en/', 'http://www.kreftregisteret.no/en/', 'http://www.biobankdenmark.dk/', 'http://www.ukbiobank.ac.uk/', 'http://www.nationale-kohorte.de/', 'http://www.framinghamheartstudy.org/', 'http://www.ckbiobank.org/site/', 'http://nationalgenebank.org/', 'http://kaimrc.med.sa/index.php?option=com_content&view=article&id=31&Itemid=28&lang=en']
